# %% [markdown]
# # CTSM-FATES Tutorial
# ## Check simple case (1 month)

# %%
import os
import xarray as xr
xr.set_options(display_style="html")
# %matplotlib inline

case = 'fates_alp1'
path = os.path.join(os.getenv('HOME'), 'archive', case, 'lnd', 'hist')
dset = xr.open_dataset(path + '/fates_alp1.clm2.h0.2000-01.nc')
dset

# %% [markdown]
# ## Check values for a few variables

# %%
dset['AREA_TREES']
# Out:
# <xarray.DataArray 'AREA_TREES' (time: 1, lndgrid: 1)>
# array([[0.248605]], dtype=float32)
# Coordinates:
#   * time     (time) object 2000-02-01 00:00:00
# Dimensions without coordinates: lndgrid
# Attributes:
#     long_name:     area occupied by woody plants
#     units:         m2
#     cell_methods:  time: mean

# %% [markdown]
# ## Check long (10 years) simulation

# %%
import xarray as xr
xr.set_options(display_style="html")
# %matplotlib inline

case = 'fates_alp1'
path = os.path.join(os.getenv('HOME'), 'archive', case, 'lnd', 'hist')
dset = xr.open_mfdataset(path + '/*.nc', combine='by_coords')
dset
# Out:
# <xarray.Dataset>
# Dimensions:                          (fates_levage: 7, fates_levagepft: 84, fates_levcacls: 2, fates_levcan: 2, fates_levcapf: 24, fates_levcnlf: 60, fates_levcnlfpf: 720, fates_levcwdsc: 4, fates_levelcwd: 4, fates_levelem: 1, fates_levfuel: 6, fates_levheight: 6, fates_levpft: 12, fates_levscag: 91, fates_levscagpf: 1092, fates_levscls: 13, fates_levscpf: 156, glc_nec: 10, hist_interval: 2, levdcmp: 25, levgrnd: 25, levlak: 10, levsoi: 20, lndgrid: 1, ltype: 9, time: 1)
# Coordinates:
#   * levgrnd                          (levgrnd) float32 0.01 0.04 ... 41.998436
#   * levlak                           (levlak) float32 0.05 0.6 ... 34.325 44.775
#   * levdcmp                          (levdcmp) float32 0.01 0.04 ... 41.998436
#   * fates_levscls                    (fates_levscls) float32 0.0 5.0 ... 100.0
#   * fates_levcacls                   (fates_levcacls) float32 0.0 5.0
#   * fates_levage                     (fates_levage) float32 0.0 1.0 ... 50.0
#   * fates_levheight                  (fates_levheight) float32 0.0 0.1 ... 10.0
#   * fates_levpft                     (fates_levpft) int32 1 2 3 4 ... 9 10 11 12
#   * fates_levfuel                    (fates_levfuel) int32 1 2 3 4 5 6
#   * fates_levcwdsc                   (fates_levcwdsc) int32 1 2 3 4
#   * fates_levcan                     (fates_levcan) int32 1 2
#   * time                             (time) object 2000-02-01 00:00:00
# Dimensions without coordinates: fates_levagepft, fates_levcapf, fates_levcnlf, fates_levcnlfpf, fates_levelcwd, fates_levelem, fates_levscag, fates_levscagpf, fates_levscpf, glc_nec, hist_interval, levsoi, lndgrid, ltype
# Data variables:
#     fates_scmap_levscag              (fates_levscag) int32 dask.array<open_da...
#     fates_agmap_levscag              (fates_levscag) int32 dask.array<open_da...
#     fates_pftmap_levscpf             (fates_levscpf) int32 dask.array<open_da...
#     fates_scmap_levscpf              (fates_levscpf) int32 dask.array<open_da...
#     fates_pftmap_levcapf             (fates_levcapf) int32 dask.array<open_da...
#     fates_camap_levcapf              (fates_levcapf) int32 dask.array<open_da...
#     fates_canmap_levcnlf             (fates_levcnlf) int32 dask.array<open_da...
#     fates_lfmap_levcnlf              (fates_levcnlf) int32 dask.array<open_da...
#     fates_canmap_levcnlfpf           (fates_levcnlfpf) int32 dask.array<open_...
#     fates_lfmap_levcnlfpf            (fates_levcnlfpf) int32 dask.array<open_...
#     fates_pftmap_levcnlfpf           (fates_levcnlfpf) int32 dask.array<open_...
#     fates_scmap_levscagpft           (fates_levscagpf) int32 dask.array<open_...
#     fates_agmap_levscagpft           (fates_levscagpf) int32 dask.array<open_...
#     fates_pftmap_levscagpft          (fates_levscagpf) int32 dask.array<open_...
#     fates_pftmap_levagepft           (fates_levagepft) int32 dask.array<open_...
#     fates_agmap_levagepft            (fates_levagepft) int32 dask.array<open_...
#     mcdate                           (time) int32 dask.array<open_dataset-724...
#     mcsec                            (time) int32 dask.array<open_dataset-724...
#     mdcur                            (time) int32 dask.array<open_dataset-724...
#     mscur                            (time) int32 dask.array<open_dataset-724...
#     nstep                            (time) int32 dask.array<open_dataset-724...
#     time_bounds                      (time, hist_interval) object dask.array<...
#     date_written                     (time) |S16 dask.array<open_dataset-7242...
#     time_written                     (time) |S16 dask.array<open_dataset-7242...
#     lon                              (lndgrid) float32 dask.array<open_datase...
#     lat                              (lndgrid) float32 dask.array<open_datase...
#     area                             (lndgrid) float32 dask.array<open_datase...
#     landfrac                         (lndgrid) float32 dask.array<open_datase...
#     landmask                         (lndgrid) float64 dask.array<open_datase...
#     pftmask                          (lndgrid) float64 dask.array<open_datase...
#     nbedrock                         (lndgrid) float64 dask.array<open_datase...
#     ZSOI                             (levgrnd, lndgrid) float32 dask.array<op...
#     DZSOI                            (levgrnd, lndgrid) float32 dask.array<op...
#     WATSAT                           (levgrnd, lndgrid) float32 dask.array<op...
#     SUCSAT                           (levgrnd, lndgrid) float32 dask.array<op...
#     BSW                              (levgrnd, lndgrid) float32 dask.array<op...
#     HKSAT                            (levgrnd, lndgrid) float32 dask.array<op...
#     ZLAKE                            (levlak, lndgrid) float32 dask.array<ope...
#     DZLAKE                           (levlak, lndgrid) float32 dask.array<ope...
#     ACTUAL_IMMOB                     (time, lndgrid) float32 dask.array<open_...
#     AGB                              (time, lndgrid) float32 dask.array<open_...
#     AGB_SCLS                         (time, fates_levscls, lndgrid) float32 d...
#     AR                               (time, lndgrid) float32 dask.array<open_...
#     AREA_BURNT_BY_PATCH_AGE          (time, fates_levage, lndgrid) float32 da...
#     AREA_PLANT                       (time, lndgrid) float32 dask.array<open_...
#     AREA_TREES                       (time, lndgrid) float32 dask.array<open_...
#     AR_CANOPY                        (time, lndgrid) float32 dask.array<open_...
#     AR_UNDERSTORY                    (time, lndgrid) float32 dask.array<open_...
#     ATM_TOPO                         (time, lndgrid) float32 dask.array<open_...
#     BA_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     BCDEP                            (time, lndgrid) float32 dask.array<open_...
#     BIOMASS_CANOPY                   (time, lndgrid) float32 dask.array<open_...
#     BIOMASS_UNDERSTORY               (time, lndgrid) float32 dask.array<open_...
#     BTRAN                            (time, lndgrid) float32 dask.array<open_...
#     BTRAN2                           (time, lndgrid) float32 dask.array<open_...
#     BTRANMN                          (time, lndgrid) float32 dask.array<open_...
#     BURNT_LITTER_FRAC_AREA_PRODUCT   (time, fates_levfuel, lndgrid) float32 d...
#     CANOPY_AREA_BY_AGE               (time, fates_levage, lndgrid) float32 da...
#     CANOPY_HEIGHT_DIST               (time, fates_levheight, lndgrid) float32 dask.array<open_dataset-72425b66f8c775bf4f8daeb845ec5fddCANOPY_HEIGHT_DIST, shape=(1, 6, 1), dtype=float32, chunksize=(1, 6, 1), chunktype=numpy.ndarray...
#     CANOPY_SPREAD                    (time, lndgrid) float32 dask.array<open_...
#     CBALANCE_ERROR_FATES             (time, lndgrid) float32 dask.array<open_...
#     CEFFLUX                          (time, lndgrid) float32 dask.array<open_...
#     CROWNAREA_CAN                    (time, fates_levcan, lndgrid) float32 da...
#     C_LBLAYER                        (time, lndgrid) float32 dask.array<open_...
#     C_STOMATA                        (time, lndgrid) float32 dask.array<open_...
#     DDBH_CANOPY_SCLS                 (time, fates_levscls, lndgrid) float32 d...
#     DDBH_UNDERSTORY_SCLS             (time, fates_levscls, lndgrid) float32 d...
#     DEMOTION_CARBONFLUX              (time, lndgrid) float32 dask.array<open_...
#     DENIT                            (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_FIRE            (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_LOGGING         (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_P2P             (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_P2S             (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_POTENTIAL       (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_S2S             (time, lndgrid) float32 dask.array<open_...
#     DISTURBANCE_RATE_TREEFALL        (time, lndgrid) float32 dask.array<open_...
#     DSL                              (time, lndgrid) float32 dask.array<open_...
#     DSTDEP                           (time, lndgrid) float32 dask.array<open_...
#     DSTFLXT                          (time, lndgrid) float32 dask.array<open_...
#     ED_NCOHORTS                      (time, lndgrid) float32 dask.array<open_...
#     ED_NPATCHES                      (time, lndgrid) float32 dask.array<open_...
#     ED_balive                        (time, lndgrid) float32 dask.array<open_...
#     ED_bdead                         (time, lndgrid) float32 dask.array<open_...
#     ED_bfineroot                     (time, lndgrid) float32 dask.array<open_...
#     ED_biomass                       (time, lndgrid) float32 dask.array<open_...
#     ED_bleaf                         (time, lndgrid) float32 dask.array<open_...
#     ED_bsapwood                      (time, lndgrid) float32 dask.array<open_...
#     ED_bstore                        (time, lndgrid) float32 dask.array<open_...
#     EFFECT_WSPEED                    (time, lndgrid) float32 dask.array<open_...
#     EFLXBUILD                        (time, lndgrid) float32 dask.array<open_...
#     EFLX_DYNBAL                      (time, lndgrid) float32 dask.array<open_...
#     EFLX_GRND_LAKE                   (time, lndgrid) float32 dask.array<open_...
#     EFLX_LH_TOT                      (time, lndgrid) float32 dask.array<open_...
#     EFLX_LH_TOT_R                    (time, lndgrid) float32 dask.array<open_...
#     ELAI                             (time, lndgrid) float32 dask.array<open_...
#     ERRH2O                           (time, lndgrid) float32 dask.array<open_...
#     ERRH2OSNO                        (time, lndgrid) float32 dask.array<open_...
#     ERROR_FATES                      (time, fates_levelem, lndgrid) float32 d...
#     ERRSEB                           (time, lndgrid) float32 dask.array<open_...
#     ERRSOI                           (time, lndgrid) float32 dask.array<open_...
#     ERRSOL                           (time, lndgrid) float32 dask.array<open_...
#     ESAI                             (time, lndgrid) float32 dask.array<open_...
#     FATES_c_to_litr_cel_c            (time, levdcmp, lndgrid) float32 dask.ar...
#     FATES_c_to_litr_lab_c            (time, levdcmp, lndgrid) float32 dask.ar...
#     FATES_c_to_litr_lig_c            (time, levdcmp, lndgrid) float32 dask.ar...
#     FCEV                             (time, lndgrid) float32 dask.array<open_...
#     FCOV                             (time, lndgrid) float32 dask.array<open_...
#     FCTR                             (time, lndgrid) float32 dask.array<open_...
#     FGEV                             (time, lndgrid) float32 dask.array<open_...
#     FGR                              (time, lndgrid) float32 dask.array<open_...
#     FGR12                            (time, lndgrid) float32 dask.array<open_...
#     FH2OSFC                          (time, lndgrid) float32 dask.array<open_...
#     FIRA                             (time, lndgrid) float32 dask.array<open_...
#     FIRA_R                           (time, lndgrid) float32 dask.array<open_...
#     FIRE                             (time, lndgrid) float32 dask.array<open_...
#     FIRE_AREA                        (time, lndgrid) float32 dask.array<open_...
#     FIRE_FLUX                        (time, fates_levelem, lndgrid) float32 d...
#     FIRE_FUEL_BULKD                  (time, lndgrid) float32 dask.array<open_...
#     FIRE_FUEL_EFF_MOIST              (time, lndgrid) float32 dask.array<open_...
#     FIRE_FUEL_MEF                    (time, lndgrid) float32 dask.array<open_...
#     FIRE_FUEL_SAV                    (time, lndgrid) float32 dask.array<open_...
#     FIRE_INTENSITY                   (time, lndgrid) float32 dask.array<open_...
#     FIRE_INTENSITY_AREA_PRODUCT      (time, lndgrid) float32 dask.array<open_...
#     FIRE_INTENSITY_BY_PATCH_AGE      (time, fates_levage, lndgrid) float32 da...
#     FIRE_NESTEROV_INDEX              (time, lndgrid) float32 dask.array<open_...
#     FIRE_R                           (time, lndgrid) float32 dask.array<open_...
#     FIRE_ROS                         (time, lndgrid) float32 dask.array<open_...
#     FIRE_ROS_AREA_PRODUCT            (time, lndgrid) float32 dask.array<open_...
#     FIRE_TFC_ROS                     (time, lndgrid) float32 dask.array<open_...
#     FIRE_TFC_ROS_AREA_PRODUCT        (time, lndgrid) float32 dask.array<open_...
#     FLDS                             (time, lndgrid) float32 dask.array<open_...
#     FNRTC                            (time, lndgrid) float32 dask.array<open_...
#     FROOT_MR                         (time, lndgrid) float32 dask.array<open_...
#     FSA                              (time, lndgrid) float32 dask.array<open_...
#     FSAT                             (time, lndgrid) float32 dask.array<open_...
#     FSDS                             (time, lndgrid) float32 dask.array<open_...
#     FSDSND                           (time, lndgrid) float32 dask.array<open_...
#     FSDSNDLN                         (time, lndgrid) float32 dask.array<open_...
#     FSDSNI                           (time, lndgrid) float32 dask.array<open_...
#     FSDSVD                           (time, lndgrid) float32 dask.array<open_...
#     FSDSVDLN                         (time, lndgrid) float32 dask.array<open_...
#     FSDSVI                           (time, lndgrid) float32 dask.array<open_...
#     FSDSVILN                         (time, lndgrid) float32 dask.array<open_...
#     FSH                              (time, lndgrid) float32 dask.array<open_...
#     FSH_G                            (time, lndgrid) float32 dask.array<open_...
#     FSH_PRECIP_CONVERSION            (time, lndgrid) float32 dask.array<open_...
#     FSH_R                            (time, lndgrid) float32 dask.array<open_...
#     FSH_RUNOFF_ICE_TO_LIQ            (time, lndgrid) float32 dask.array<open_...
#     FSH_TO_COUPLER                   (time, lndgrid) float32 dask.array<open_...
#     FSH_V                            (time, lndgrid) float32 dask.array<open_...
#     FSM                              (time, lndgrid) float32 dask.array<open_...
#     FSNO                             (time, lndgrid) float32 dask.array<open_...
#     FSNO_EFF                         (time, lndgrid) float32 dask.array<open_...
#     FSR                              (time, lndgrid) float32 dask.array<open_...
#     FSRND                            (time, lndgrid) float32 dask.array<open_...
#     FSRNDLN                          (time, lndgrid) float32 dask.array<open_...
#     FSRNI                            (time, lndgrid) float32 dask.array<open_...
#     FSRVD                            (time, lndgrid) float32 dask.array<open_...
#     FSRVDLN                          (time, lndgrid) float32 dask.array<open_...
#     FSRVI                            (time, lndgrid) float32 dask.array<open_...
#     FUEL_MOISTURE_NFSC               (time, fates_levfuel, lndgrid) float32 d...
#     Fire_Closs                       (time, lndgrid) float32 dask.array<open_...
#     GPP                              (time, lndgrid) float32 dask.array<open_...
#     GPP_CANOPY                       (time, lndgrid) float32 dask.array<open_...
#     GPP_UNDERSTORY                   (time, lndgrid) float32 dask.array<open_...
#     GROSS_NMIN                       (time, lndgrid) float32 dask.array<open_...
#     GROWTH_RESP                      (time, lndgrid) float32 dask.array<open_...
#     GSSHA                            (time, lndgrid) float32 dask.array<open_...
#     GSSHALN                          (time, lndgrid) float32 dask.array<open_...
#     GSSUN                            (time, lndgrid) float32 dask.array<open_...
#     GSSUNLN                          (time, lndgrid) float32 dask.array<open_...
#     H2OCAN                           (time, lndgrid) float32 dask.array<open_...
#     H2OSFC                           (time, lndgrid) float32 dask.array<open_...
#     H2OSNO                           (time, lndgrid) float32 dask.array<open_...
#     H2OSNO_TOP                       (time, lndgrid) float32 dask.array<open_...
#     H2OSOI                           (time, levsoi, lndgrid) float32 dask.arr...
#     HARVEST_CARBON_FLUX              (time, lndgrid) float32 dask.array<open_...
#     HEAT_CONTENT1                    (time, lndgrid) float32 dask.array<open_...
#     HEAT_FROM_AC                     (time, lndgrid) float32 dask.array<open_...
#     HIA                              (time, lndgrid) float32 dask.array<open_...
#     HIA_R                            (time, lndgrid) float32 dask.array<open_...
#     HIA_U                            (time, lndgrid) float32 dask.array<open_...
#     HR                               (time, lndgrid) float32 dask.array<open_...
#     HR_vr                            (time, levsoi, lndgrid) float32 dask.arr...
#     HTOP                             (time, lndgrid) float32 dask.array<open_...
#     HUMIDEX                          (time, lndgrid) float32 dask.array<open_...
#     HUMIDEX_R                        (time, lndgrid) float32 dask.array<open_...
#     HUMIDEX_U                        (time, lndgrid) float32 dask.array<open_...
#     ICE_CONTENT1                     (time, lndgrid) float32 dask.array<open_...
#     LAISHA                           (time, lndgrid) float32 dask.array<open_...
#     LAISUN                           (time, lndgrid) float32 dask.array<open_...
#     LAI_BY_AGE                       (time, fates_levage, lndgrid) float32 da...
#     LAI_CANOPY_SCLS                  (time, fates_levscls, lndgrid) float32 d...
#     LAI_UNDERSTORY_SCLS              (time, fates_levscls, lndgrid) float32 d...
#     LAKEICEFRAC_SURF                 (time, lndgrid) float32 dask.array<open_...
#     LAKEICETHICK                     (time, lndgrid) float32 dask.array<open_...
#     LEAFC                            (time, lndgrid) float32 dask.array<open_...
#     LEAF_HEIGHT_DIST                 (time, fates_levheight, lndgrid) float32 dask.array<open_dataset-72425b66f8c775bf4f8daeb845ec5fddLEAF_HEIGHT_DIST, shape=(1, 6, 1), dtype=float32, chunksize=(1, 6, 1), chunktype=numpy.ndarray...
#     LEAF_MR                          (time, lndgrid) float32 dask.array<open_...
#     LIQCAN                           (time, lndgrid) float32 dask.array<open_...
#     LIQUID_CONTENT1                  (time, lndgrid) float32 dask.array<open_...
#     LITR1C                           (time, lndgrid) float32 dask.array<open_...
#     LITR1C_vr                        (time, levsoi, lndgrid) float32 dask.arr...
#     LITR1N                           (time, lndgrid) float32 dask.array<open_...
#     LITR1N_vr                        (time, levdcmp, lndgrid) float32 dask.ar...
#     LITR2C                           (time, lndgrid) float32 dask.array<open_...
#     LITR2C_vr                        (time, levsoi, lndgrid) float32 dask.arr...
#     LITR2N                           (time, lndgrid) float32 dask.array<open_...
#     LITR2N_vr                        (time, levdcmp, lndgrid) float32 dask.ar...
#     LITR3C                           (time, lndgrid) float32 dask.array<open_...
#     LITR3C_vr                        (time, levsoi, lndgrid) float32 dask.arr...
#     LITR3N                           (time, lndgrid) float32 dask.array<open_...
#     LITR3N_vr                        (time, levdcmp, lndgrid) float32 dask.ar...
#     LITTERC_HR                       (time, lndgrid) float32 dask.array<open_...
#     LITTER_CWD                       (time, fates_levelcwd, lndgrid) float32 ...
#     LITTER_CWD_AG_ELEM               (time, fates_levelem, lndgrid) float32 d...
#     LITTER_CWD_BG_ELEM               (time, fates_levelem, lndgrid) float32 d...
#     LITTER_FINES_AG_ELEM             (time, fates_levelem, lndgrid) float32 d...
#     LITTER_FINES_BG_ELEM             (time, fates_levelem, lndgrid) float32 d...
#     LITTER_IN                        (time, lndgrid) float32 dask.array<open_...
#     LITTER_IN_ELEM                   (time, fates_levelem, lndgrid) float32 d...
#     LITTER_OUT                       (time, lndgrid) float32 dask.array<open_...
#     LITTER_OUT_ELEM                  (time, fates_levelem, lndgrid) float32 d...
#     LIVECROOT_MR                     (time, lndgrid) float32 dask.array<open_...
#     LIVESTEM_MR                      (time, lndgrid) float32 dask.array<open_...
#     LNC                              (time, lndgrid) float32 dask.array<open_...
#     M10_CACLS                        (time, fates_levcacls, lndgrid) float32 ...
#     M10_SCLS                         (time, fates_levscls, lndgrid) float32 d...
#     M1_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M2_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M3_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M4_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M5_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M6_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M7_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M8_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     M9_SCLS                          (time, fates_levscls, lndgrid) float32 d...
#     MAINT_RESP                       (time, lndgrid) float32 dask.array<open_...
#     MORTALITY                        (time, fates_levpft, lndgrid) float32 da...
#     MORTALITY_CANOPY_SCLS            (time, fates_levscls, lndgrid) float32 d...
#     MORTALITY_CARBONFLUX_CANOPY      (time, lndgrid) float32 dask.array<open_...
#     MORTALITY_CARBONFLUX_UNDERSTORY  (time, lndgrid) float32 dask.array<open_...
#     MORTALITY_UNDERSTORY_SCLS        (time, fates_levscls, lndgrid) float32 d...
#     NDEP_TO_SMINN                    (time, lndgrid) float32 dask.array<open_...
#     NEP                              (time, lndgrid) float32 dask.array<open_...
#     NET_NMIN                         (time, lndgrid) float32 dask.array<open_...
#     NFIX_TO_SMINN                    (time, lndgrid) float32 dask.array<open_...
#     NPLANT_CACLS                     (time, fates_levcacls, lndgrid) float32 ...
#     NPLANT_CANOPY_SCLS               (time, fates_levscls, lndgrid) float32 d...
#     NPLANT_SCAG                      (time, fates_levscag, lndgrid) float32 d...
#     NPLANT_SCLS                      (time, fates_levscls, lndgrid) float32 d...
#     NPLANT_UNDERSTORY_SCLS           (time, fates_levscls, lndgrid) float32 d...
#     NPP                              (time, lndgrid) float32 dask.array<open_...
#     NPP_CROOT                        (time, lndgrid) float32 dask.array<open_...
#     NPP_FROOT                        (time, lndgrid) float32 dask.array<open_...
#     NPP_LEAF                         (time, lndgrid) float32 dask.array<open_...
#     NPP_SEED                         (time, lndgrid) float32 dask.array<open_...
#     NPP_STEM                         (time, lndgrid) float32 dask.array<open_...
#     NPP_STOR                         (time, lndgrid) float32 dask.array<open_...
#     OCDEP                            (time, lndgrid) float32 dask.array<open_...
#     O_SCALAR                         (time, levsoi, lndgrid) float32 dask.arr...
#     PARVEGLN                         (time, lndgrid) float32 dask.array<open_...
#     PATCH_AREA_BY_AGE                (time, fates_levage, lndgrid) float32 da...
#     PBOT                             (time, lndgrid) float32 dask.array<open_...
#     PCO2                             (time, lndgrid) float32 dask.array<open_...
#     PCT_GLC_MEC                      (time, glc_nec, lndgrid) float32 dask.ar...
#     PCT_LANDUNIT                     (time, ltype, lndgrid) float32 dask.arra...
#     PFTbiomass                       (time, fates_levpft, lndgrid) float32 da...
#     PFTleafbiomass                   (time, fates_levpft, lndgrid) float32 da...
#     PFTnindivs                       (time, fates_levpft, lndgrid) float32 da...
#     PFTstorebiomass                  (time, fates_levpft, lndgrid) float32 da...
#     POTENTIAL_IMMOB                  (time, lndgrid) float32 dask.array<open_...
#     PRIMARYLAND_PATCHFUSION_ERROR    (time, lndgrid) float32 dask.array<open_...
#     PROMOTION_CARBONFLUX             (time, lndgrid) float32 dask.array<open_...
#     Q2M                              (time, lndgrid) float32 dask.array<open_...
#     QBOT                             (time, lndgrid) float32 dask.array<open_...
#     QCHARGE                          (time, lndgrid) float32 dask.array<open_...
#     QDRAI                            (time, lndgrid) float32 dask.array<open_...
#     QDRAI_PERCH                      (time, lndgrid) float32 dask.array<open_...
#     QDRAI_XS                         (time, lndgrid) float32 dask.array<open_...
#     QFLOOD                           (time, lndgrid) float32 dask.array<open_...
#     QFLX_EVAP_TOT                    (time, lndgrid) float32 dask.array<open_...
#     QFLX_ICE_DYNBAL                  (time, lndgrid) float32 dask.array<open_...
#     QFLX_LIQDEW_TO_TOP_LAYER         (time, lndgrid) float32 dask.array<open_...
#     QFLX_LIQEVAP_FROM_TOP_LAYER      (time, lndgrid) float32 dask.array<open_...
#     QFLX_LIQ_DYNBAL                  (time, lndgrid) float32 dask.array<open_...
#     QFLX_SNOW_DRAIN                  (time, lndgrid) float32 dask.array<open_...
#     QFLX_SNOW_DRAIN_ICE              (time, lndgrid) float32 dask.array<open_...
#     QFLX_SOLIDDEW_TO_TOP_LAYER       (time, lndgrid) float32 dask.array<open_...
#     QFLX_SOLIDEVAP_FROM_TOP_LAYER    (time, lndgrid) float32 dask.array<open_...
#     QH2OSFC                          (time, lndgrid) float32 dask.array<open_...
#     QICE                             (time, lndgrid) float32 dask.array<open_...
#     QICE_FRZ                         (time, lndgrid) float32 dask.array<open_...
#     QICE_MELT                        (time, lndgrid) float32 dask.array<open_...
#     QINFL                            (time, lndgrid) float32 dask.array<open_...
#     QINTR                            (time, lndgrid) float32 dask.array<open_...
#     QIRRIG_FROM_GW_CONFINED          (time, lndgrid) float32 dask.array<open_...
#     QIRRIG_FROM_GW_UNCONFINED        (time, lndgrid) float32 dask.array<open_...
#     QIRRIG_FROM_SURFACE              (time, lndgrid) float32 dask.array<open_...
#     QOVER                            (time, lndgrid) float32 dask.array<open_...
#     QRGWL                            (time, lndgrid) float32 dask.array<open_...
#     QRUNOFF                          (time, lndgrid) float32 dask.array<open_...
#     QRUNOFF_ICE                      (time, lndgrid) float32 dask.array<open_...
#     QRUNOFF_ICE_TO_COUPLER           (time, lndgrid) float32 dask.array<open_...
#     QRUNOFF_TO_COUPLER               (time, lndgrid) float32 dask.array<open_...
#     QSNOCPLIQ                        (time, lndgrid) float32 dask.array<open_...
#     QSNOEVAP                         (time, lndgrid) float32 dask.array<open_...
#     QSNOFRZ                          (time, lndgrid) float32 dask.array<open_...
#     QSNOFRZ_ICE                      (time, lndgrid) float32 dask.array<open_...
#     QSNOMELT                         (time, lndgrid) float32 dask.array<open_...
#     QSNOMELT_ICE                     (time, lndgrid) float32 dask.array<open_...
#     QSNOUNLOAD                       (time, lndgrid) float32 dask.array<open_...
#     QSNO_TEMPUNLOAD                  (time, lndgrid) float32 dask.array<open_...
#     QSNO_WINDUNLOAD                  (time, lndgrid) float32 dask.array<open_...
#     QSNWCPICE                        (time, lndgrid) float32 dask.array<open_...
#     QSOIL                            (time, lndgrid) float32 dask.array<open_...
#     QSOIL_ICE                        (time, lndgrid) float32 dask.array<open_...
#     QVEGE                            (time, lndgrid) float32 dask.array<open_...
#     QVEGT                            (time, lndgrid) float32 dask.array<open_...
#     RAIN                             (time, lndgrid) float32 dask.array<open_...
#     RAIN_FROM_ATM                    (time, lndgrid) float32 dask.array<open_...
#     RECRUITMENT                      (time, fates_levpft, lndgrid) float32 da...
#     REPROC                           (time, lndgrid) float32 dask.array<open_...
#     RH2M                             (time, lndgrid) float32 dask.array<open_...
#     RSCANOPY                         (time, lndgrid) float32 dask.array<open_...
#     RSSHA                            (time, lndgrid) float32 dask.array<open_...
#     RSSUN                            (time, lndgrid) float32 dask.array<open_...
#     SABG                             (time, lndgrid) float32 dask.array<open_...
#     SABG_PEN                         (time, lndgrid) float32 dask.array<open_...
#     SABV                             (time, lndgrid) float32 dask.array<open_...
#     SAPWC                            (time, lndgrid) float32 dask.array<open_...
#     SCORCH_HEIGHT                    (time, fates_levagepft, lndgrid) float32 dask.array<open_dataset-72425b66f8c775bf4f8daeb845ec5fddSCORCH_HEIGHT, shape=(1, 84, 1), dtype=float32, chunksize=(1, 84, 1), chunktype=numpy.ndarray...
#     SEEDS_IN                         (time, lndgrid) float32 dask.array<open_...
#     SEEDS_IN_EXTERN_ELEM             (time, fates_levelem, lndgrid) float32 d...
#     SEEDS_IN_LOCAL_ELEM              (time, fates_levelem, lndgrid) float32 d...
#     SEED_BANK                        (time, lndgrid) float32 dask.array<open_...
#     SEED_BANK_ELEM                   (time, fates_levelem, lndgrid) float32 d...
#     SEED_DECAY_ELEM                  (time, fates_levelem, lndgrid) float32 d...
#     SEED_GERM_ELEM                   (time, fates_levelem, lndgrid) float32 d...
#     SITE_COLD_STATUS                 (time, lndgrid) float32 dask.array<open_...
#     SITE_DAYSINCE_COLDLEAFOFF        (time, lndgrid) timedelta64[ns] dask.arr...
#     SITE_DAYSINCE_COLDLEAFON         (time, lndgrid) timedelta64[ns] dask.arr...
#     SITE_DAYSINCE_DROUGHTLEAFOFF     (time, lndgrid) timedelta64[ns] dask.arr...
#     SITE_DAYSINCE_DROUGHTLEAFON      (time, lndgrid) timedelta64[ns] dask.arr...
#     SITE_DROUGHT_STATUS              (time, lndgrid) float32 dask.array<open_...
#     SITE_GDD                         (time, lndgrid) float32 dask.array<open_...
#     SITE_MEANLIQVOL_DROUGHTPHEN      (time, lndgrid) float32 dask.array<open_...
#     SITE_NCHILLDAYS                  (time, lndgrid) timedelta64[ns] dask.arr...
#     SITE_NCOLDDAYS                   (time, lndgrid) timedelta64[ns] dask.arr...
#     SMINN                            (time, lndgrid) float32 dask.array<open_...
#     SMINN_LEACHED                    (time, lndgrid) float32 dask.array<open_...
#     SMINN_TO_PLANT                   (time, lndgrid) float32 dask.array<open_...
#     SMINN_vr                         (time, levsoi, lndgrid) float32 dask.arr...
#     SMP                              (time, levgrnd, lndgrid) float32 dask.ar...
#     SNOBCMCL                         (time, lndgrid) float32 dask.array<open_...
#     SNOBCMSL                         (time, lndgrid) float32 dask.array<open_...
#     SNOCAN                           (time, lndgrid) float32 dask.array<open_...
#     SNODSTMCL                        (time, lndgrid) float32 dask.array<open_...
#     SNODSTMSL                        (time, lndgrid) float32 dask.array<open_...
#     SNOFSRND                         (time, lndgrid) float32 dask.array<open_...
#     SNOFSRNI                         (time, lndgrid) float32 dask.array<open_...
#     SNOFSRVD                         (time, lndgrid) float32 dask.array<open_...
#     SNOFSRVI                         (time, lndgrid) float32 dask.array<open_...
#     SNOINTABS                        (time, lndgrid) float32 dask.array<open_...
#     SNOOCMCL                         (time, lndgrid) float32 dask.array<open_...
#     SNOOCMSL                         (time, lndgrid) float32 dask.array<open_...
#     SNOTXMASS                        (time, lndgrid) float32 dask.array<open_...
#     SNOW                             (time, lndgrid) float32 dask.array<open_...
#     SNOWDP                           (time, lndgrid) float32 dask.array<open_...
#     SNOWICE                          (time, lndgrid) float32 dask.array<open_...
#     SNOWLIQ                          (time, lndgrid) float32 dask.array<open_...
#     SNOW_DEPTH                       (time, lndgrid) float32 dask.array<open_...
#     SNOW_FROM_ATM                    (time, lndgrid) float32 dask.array<open_...
#     SNOW_PERSISTENCE                 (time, lndgrid) timedelta64[ns] dask.arr...
#     SNOW_SINKS                       (time, lndgrid) float32 dask.array<open_...
#     SNOW_SOURCES                     (time, lndgrid) float32 dask.array<open_...
#     SOIL1C                           (time, lndgrid) float32 dask.array<open_...
#     SOIL1C_vr                        (time, levsoi, lndgrid) float32 dask.arr...
#     SOIL1N                           (time, lndgrid) float32 dask.array<open_...
#     SOIL1N_vr                        (time, levdcmp, lndgrid) float32 dask.ar...
#     SOIL2C                           (time, lndgrid) float32 dask.array<open_...
#     SOIL2C_vr                        (time, levsoi, lndgrid) float32 dask.arr...
#     SOIL2N                           (time, lndgrid) float32 dask.array<open_...
#     SOIL2N_vr                        (time, levdcmp, lndgrid) float32 dask.ar...
#     SOIL3C                           (time, lndgrid) float32 dask.array<open_...
#     SOIL3C_vr                        (time, levsoi, lndgrid) float32 dask.arr...
#     SOIL3N                           (time, lndgrid) float32 dask.array<open_...
#     SOIL3N_vr                        (time, levdcmp, lndgrid) float32 dask.ar...
#     SOILC_HR                         (time, lndgrid) float32 dask.array<open_...
#     SOILC_vr                         (time, levsoi, lndgrid) float32 dask.arr...
#     SOILICE                          (time, levsoi, lndgrid) float32 dask.arr...
#     SOILLIQ                          (time, levsoi, lndgrid) float32 dask.arr...
#     SOILN_vr                         (time, levdcmp, lndgrid) float32 dask.ar...
#     SOILRESIS                        (time, lndgrid) float32 dask.array<open_...
#     SOILWATER_10CM                   (time, lndgrid) float32 dask.array<open_...
#     SOMC_FIRE                        (time, lndgrid) float32 dask.array<open_...
#     SOM_C_LEACHED                    (time, lndgrid) float32 dask.array<open_...
#     STOREC                           (time, lndgrid) float32 dask.array<open_...
#     SUM_FUEL                         (time, lndgrid) float32 dask.array<open_...
#     SUM_FUEL_BY_PATCH_AGE            (time, fates_levage, lndgrid) float32 da...
#     SUPPLEMENT_TO_SMINN              (time, lndgrid) float32 dask.array<open_...
#     SWBGT                            (time, lndgrid) float32 dask.array<open_...
#     SWBGT_R                          (time, lndgrid) float32 dask.array<open_...
#     SWBGT_U                          (time, lndgrid) float32 dask.array<open_...
#     TAUX                             (time, lndgrid) float32 dask.array<open_...
#     TAUY                             (time, lndgrid) float32 dask.array<open_...
#     TBOT                             (time, lndgrid) float32 dask.array<open_...
#     TBUILD                           (time, lndgrid) float32 dask.array<open_...
#     TG                               (time, lndgrid) float32 dask.array<open_...
#     TH2OSFC                          (time, lndgrid) float32 dask.array<open_...
#     THBOT                            (time, lndgrid) float32 dask.array<open_...
#     TKE1                             (time, lndgrid) float32 dask.array<open_...
#     TLAI                             (time, lndgrid) float32 dask.array<open_...
#     TLAKE                            (time, levlak, lndgrid) float32 dask.arr...
#     TOTLITC                          (time, lndgrid) float32 dask.array<open_...
#     TOTLITC_1m                       (time, lndgrid) float32 dask.array<open_...
#     TOTLITN                          (time, lndgrid) float32 dask.array<open_...
#     TOTLITN_1m                       (time, lndgrid) float32 dask.array<open_...
#     TOTSOILICE                       (time, lndgrid) float32 dask.array<open_...
#     TOTSOILLIQ                       (time, lndgrid) float32 dask.array<open_...
#     TOTSOMC                          (time, lndgrid) float32 dask.array<open_...
#     TOTSOMC_1m                       (time, lndgrid) float32 dask.array<open_...
#     TOTSOMN                          (time, lndgrid) float32 dask.array<open_...
#     TOTSOMN_1m                       (time, lndgrid) float32 dask.array<open_...
#     TOTVEGC                          (time, lndgrid) float32 dask.array<open_...
#     TREFMNAV                         (time, lndgrid) float32 dask.array<open_...
#     TREFMXAV                         (time, lndgrid) float32 dask.array<open_...
#     TRIMMING                         (time, lndgrid) float32 dask.array<open_...
#     TSA                              (time, lndgrid) float32 dask.array<open_...
#     TSAI                             (time, lndgrid) float32 dask.array<open_...
#     TSKIN                            (time, lndgrid) float32 dask.array<open_...
#     TSL                              (time, lndgrid) float32 dask.array<open_...
#     TSOI                             (time, levgrnd, lndgrid) float32 dask.ar...
#     TSOI_10CM                        (time, lndgrid) float32 dask.array<open_...
#     TSOI_ICE                         (time, levgrnd, lndgrid) float32 dask.ar...
#     TV                               (time, lndgrid) float32 dask.array<open_...
#     TWS                              (time, lndgrid) float32 dask.array<open_...
#     T_SCALAR                         (time, levsoi, lndgrid) float32 dask.arr...
#     U10                              (time, lndgrid) float32 dask.array<open_...
#     U10_DUST                         (time, lndgrid) float32 dask.array<open_...
#     URBAN_AC                         (time, lndgrid) float32 dask.array<open_...
#     URBAN_HEAT                       (time, lndgrid) float32 dask.array<open_...
#     VOLR                             (time, lndgrid) float32 dask.array<open_...
#     VOLRMCH                          (time, lndgrid) float32 dask.array<open_...
#     WA                               (time, lndgrid) float32 dask.array<open_...
#     WASTEHEAT                        (time, lndgrid) float32 dask.array<open_...
#     WBT                              (time, lndgrid) float32 dask.array<open_...
#     WBT_R                            (time, lndgrid) float32 dask.array<open_...
#     WBT_U                            (time, lndgrid) float32 dask.array<open_...
#     WIND                             (time, lndgrid) float32 dask.array<open_...
#     W_SCALAR                         (time, levsoi, lndgrid) float32 dask.arr...
#     ZBOT                             (time, lndgrid) float32 dask.array<open_...
#     ZWT                              (time, lndgrid) float32 dask.array<open_...
#     ZWT_PERCH                        (time, lndgrid) float32 dask.array<open_...
# Attributes:
#     title:                                     CLM History file information
#     comment:                                   NOTE: None of the variables ar...
#     Conventions:                               CF-1.0
#     history:                                   created on 11/13/20 14:45:24
#     source:                                    Community Terrestrial Systems ...
#     hostname:                                  espresso
#     username:                                  jovyan
#     version:                                   unknown
#     revision_id:                               $Id: histFileMod.F90 42903 201...
#     case_title:                                UNSET
#     case_id:                                   fates_alp1
#     Surface_dataset:                           surfdata_ALP1_simyr2000.nc
#     Initial_conditions_dataset:                arbitrary initialization
#     PFT_physiological_constants_dataset:       clm5_params.c200402.nc
#     ltype_vegetated_or_bare_soil:              1
#     ltype_crop:                                2
#     ltype_UNUSED:                              3
#     ltype_landice_multiple_elevation_classes:  4
#     ltype_deep_lake:                           5
#     ltype_wetland:                             6
#     ltype_urban_tbd:                           7
#     ltype_urban_hd:                            8
#     ltype_urban_md:                            9
#     ctype_vegetated_or_bare_soil:              1
#     ctype_crop:                                2
#     ctype_crop_noncompete:                     2*100+m, m=cft_lb,cft_ub
#     ctype_landice:                             3
#     ctype_landice_multiple_elevation_classes:  4*100+m, m=1,glcnec
#     ctype_deep_lake:                           5
#     ctype_wetland:                             6
#     ctype_urban_roof:                          71
#     ctype_urban_sunwall:                       72
#     ctype_urban_shadewall:                     73
#     ctype_urban_impervious_road:               74
#     ctype_urban_pervious_road:                 75
#     time_period_freq:                          month_1

# %%
dset['AREA_TREES']

# %%
import matplotlib.pyplot as plt
fig = plt.figure(1, figsize=[14,7])
ax = plt.subplot(1, 1, 1)
dset['AREA_TREES'].plot(ax=ax)
ax.set_title(dset['AREA_TREES'].long_name)
fig.savefig('AREA_TREES.png')

# %%
p = dset['CANOPY_HEIGHT_DIST'].plot(aspect=3, size=6, col_wrap=1, col='fates_levheight')
p.fig.savefig('CANOPY_HEIGHT_DIST.png')
